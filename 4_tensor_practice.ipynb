# %% [markdown]
# <a href="https://colab.research.google.com/github/eeeewyz/Pytorch/blob/main/tensor_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
#shape
a=torch.tensor([1.0])

# %%
a.shape
# Out:
# torch.Size([1])

# %%
a=a.unsqueeze(0)

# %%
a.shape
# Out:
# torch.Size([1, 1])

# %%
a=a.unsqueeze(1)
a.shape
# Out:
# torch.Size([1, 1, 1])

# %%
a=a.squeeze()
a.shape
# Out:
# torch.Size([])

# %%
#slicing
x=torch.tensor([[2.8,5.6],[3.5,2.5],[5.6,7.3]])
x[0]
# Out:
# tensor([2.8000, 5.6000])

# %%
x[:,0]
# Out:
# tensor([2.8000, 3.5000, 5.6000])

# %%
# transfor to number
y=torch.tensor([2.8])
y=y.item()
y
# Out:
# 2.799999952316284
